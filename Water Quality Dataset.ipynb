# %% [markdown]
# # Open Data Project - Water Quality in NSW
#
# - This notebook is the panda version of my data from water quality
# - Total of 9 regions
# - define "Clean water"/"unclean water"
#
# By Russell Kang, z5257037

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)

# %%
saved_style_state = matplotlib.rcParams.copy() #give us a style state to go back to

# %%
my_csvs = {'Dataset - Water Quality/1_Regolith_quality.csv': '',
           'Dataset - Water Quality/1_Regolith_quality.csv' 
          }

for f in my_csvs:
    my_csvs[f] = pd.read_csv(f)
    print(f)
my_csvs
# Out:
# Dataset - Water Quality/1_Regolith_quality.csv
# {'Dataset - Water Quality/1_Regolith_quality.csv':   Station No Sample Collection Date        Data Quality Description  \
#  0   GW011996             12/07/1974  DATA APPROVAL: QUALITY UNKNOWN
#  1   GW036701             03/06/1987  DATA APPROVAL: QUALITY UNKNOWN
#  2   GW053713             30/03/1983  DATA APPROVAL: QUALITY UNKNOWN
#  3   GW053713             28/03/1985  DATA APPROVAL: QUALITY UNKNOWN
#  4   GW053713             13/01/1989  DATA APPROVAL: QUALITY UNKNOWN
#
#     Alkalinity as Bicarbonate (HCO3) Units  Calcium as Ca - total Units.1  \
#  0                          634.5768  mg/L                149.298    mg/L
#  1                          106.2001  mg/L                  0.960    mg/L
#  2                            1.2020  mg/L                  1.000    mg/L
#  3                            0.6102  mg/L                    NaN    mg/L
#  4                            6.5000  mg/L                  1.100    mg/L
#
#     Chloride as Cl Units.2  Electrical Conductivity @25 C  ... Units.66  \
#  0       1276.3080    mg/L                         4800.0  ...
#  1         30.4600    mg/L                          370.0  ...
#  2         17.9995    mg/L                           65.0  ...
#  3         17.0174    mg/L                           77.0  ...
#  4         18.1000    mg/L                           79.0  ...
#
#    Molybdenum as Mo - total Units.67  Nickel as Ni - total Units.68  \
#  0
#  1
#  2
#  3
#  4
#
#     Silver as Ag - total Units.69  Unnamed: 143 Units.70  Screen_code
#  0                                                   NaN            I
#  1                                                   NaN            E
#  2                                                   NaN            T
#  3                                                   NaN            T
#  4                                                   NaN            T
#
#  [5 rows x 146 columns]}

# %%
my_csvs
# Out:
# {'Dataset - Water Quality/1_Regolith_quality.csv':   Station No Sample Collection Date        Data Quality Description  \
#  0   GW011996             12/07/1974  DATA APPROVAL: QUALITY UNKNOWN
#  1   GW036701             03/06/1987  DATA APPROVAL: QUALITY UNKNOWN
#  2   GW053713             30/03/1983  DATA APPROVAL: QUALITY UNKNOWN
#  3   GW053713             28/03/1985  DATA APPROVAL: QUALITY UNKNOWN
#  4   GW053713             13/01/1989  DATA APPROVAL: QUALITY UNKNOWN
#
#     Alkalinity as Bicarbonate (HCO3) Units  Calcium as Ca - total Units.1  \
#  0                          634.5768  mg/L                149.298    mg/L
#  1                          106.2001  mg/L                  0.960    mg/L
#  2                            1.2020  mg/L                  1.000    mg/L
#  3                            0.6102  mg/L                    NaN    mg/L
#  4                            6.5000  mg/L                  1.100    mg/L
#
#     Chloride as Cl Units.2  Electrical Conductivity @25 C  ... Units.66  \
#  0       1276.3080    mg/L                         4800.0  ...
#  1         30.4600    mg/L                          370.0  ...
#  2         17.9995    mg/L                           65.0  ...
#  3         17.0174    mg/L                           77.0  ...
#  4         18.1000    mg/L                           79.0  ...
#
#    Molybdenum as Mo - total Units.67  Nickel as Ni - total Units.68  \
#  0
#  1
#  2
#  3
#  4
#
#     Silver as Ag - total Units.69  Unnamed: 143 Units.70  Screen_code
#  0                                                   NaN            I
#  1                                                   NaN            E
#  2                                                   NaN            T
#  3                                                   NaN            T
#  4                                                   NaN            T
#
#  [5 rows x 146 columns]}

# %%
my_csvs['Dataset - Water Quality/1_Regolith_quality.csv']
# Out:
#   Station No Sample Collection Date        Data Quality Description  \
# 0   GW011996             12/07/1974  DATA APPROVAL: QUALITY UNKNOWN
# 1   GW036701             03/06/1987  DATA APPROVAL: QUALITY UNKNOWN
# 2   GW053713             30/03/1983  DATA APPROVAL: QUALITY UNKNOWN
# 3   GW053713             28/03/1985  DATA APPROVAL: QUALITY UNKNOWN
# 4   GW053713             13/01/1989  DATA APPROVAL: QUALITY UNKNOWN
#
#    Alkalinity as Bicarbonate (HCO3) Units  Calcium as Ca - total Units.1  \
# 0                          634.5768  mg/L                149.298    mg/L
# 1                          106.2001  mg/L                  0.960    mg/L
# 2                            1.2020  mg/L                  1.000    mg/L
# 3                            0.6102  mg/L                    NaN    mg/L
# 4                            6.5000  mg/L                  1.100    mg/L
#
#    Chloride as Cl Units.2  Electrical Conductivity @25 C  ... Units.66  \
# 0       1276.3080    mg/L                         4800.0  ...
# 1         30.4600    mg/L                          370.0  ...
# 2         17.9995    mg/L                           65.0  ...
# 3         17.0174    mg/L                           77.0  ...
# 4         18.1000    mg/L                           79.0  ...
#
#   Molybdenum as Mo - total Units.67  Nickel as Ni - total Units.68  \
# 0
# 1
# 2
# 3
# 4
#
#    Silver as Ag - total Units.69  Unnamed: 143 Units.70  Screen_code
# 0                                                   NaN            I
# 1                                                   NaN            E
# 2                                                   NaN            T
# 3                                                   NaN            T
# 4                                                   NaN            T
#
# [5 rows x 146 columns]
